# %% [markdown]
# # Capstone Project_1 Data Story (EDA II)
#
# "Prediction of telemarketing conversion probability using bank user dataset"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
bank_data = pd.read_csv('bankdata.csv')

# %%
bank_data
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %% [markdown]
# bank_data

# %%
bank_data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# 1. Can you count something interesting?

# %%
bank_data['age'].value_counts().head(10)
# Out:
# 34    231
# 32    224
# 31    199
# 36    188
# 33    186
# 35    180
# 37    161
# 38    159
# 30    150
# 40    142
# Name: age, dtype: int64

# %%
bank_data['balance'].value_counts().head(10)
# Out:
# 0      357
# 2       24
# 1       15
# 4       13
# 23      11
# 5       11
# 179     10
# 6       10
# 14      10
# 35      10
# Name: balance, dtype: int64

# %%
bank_data['day'].value_counts().head(10)
# Out:
# 20    257
# 18    226
# 19    201
# 21    198
# 14    195
# 17    191
# 7     190
# 6     187
# 28    181
# 5     181
# Name: day, dtype: int64

# %%
bank_data['duration'].value_counts().head(10)
# Out:
# 123    27
# 104    25
# 119    23
# 106    22
# 77     22
# 121    22
# 58     22
# 71     20
# 168    20
# 161    19
# Name: duration, dtype: int64

# %%
bank_data['campaign'].value_counts().head(10)
# Out:
# 1     1734
# 2     1264
# 3      558
# 4      325
# 5      167
# 6      155
# 7       75
# 8       56
# 9       30
# 10      27
# Name: campaign, dtype: int64

# %%
bank_data['pdays'].value_counts().head(10)
# Out:
# -1      3705
#  182      23
#  183      20
#  363      12
#  92       12
#  91       11
#  169      10
#  181      10
#  370       9
#  364       9
# Name: pdays, dtype: int64

# %%
bank_data['previous'].value_counts().head(10)
# Out:
# 0    3705
# 1     286
# 2     193
# 3     113
# 4      78
# 5      47
# 6      25
# 7      22
# 8      18
# 9      10
# Name: previous, dtype: int64

# %%
bank_data['job'].value_counts().head(10)
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# Name: job, dtype: int64

# %%
bank_data['marital'].value_counts().head(10)
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
bank_data['education'].value_counts().head(10)
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
bank_data['default'].value_counts().head(10)
# Out:
# no     4445
# yes      76
# Name: default, dtype: int64

# %%
bank_data['housing'].value_counts().head(10)
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
bank_data['loan'].value_counts().head(10)
# Out:
# no     3830
# yes     691
# Name: loan, dtype: int64

# %%
bank_data['contact'].value_counts().head(10)
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
bank_data['month'].value_counts().head(10)
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# Name: month, dtype: int64

# %%
bank_data['poutcome'].value_counts().head(10)
# Out:
# unknown    3705
# failure     490
# other       197
# success     129
# Name: poutcome, dtype: int64

# %%
bank_data['y'].value_counts().head(10)
# Out:
# no     4000
# yes     521
# Name: y, dtype: int64

# %% [markdown]
# These counts tells us that only 521/4521 people subscribed

# %% [markdown]
# 2.  Can you find trends (e.g. high, low, increasing, decreasing, anomalies)?

# %%
bank_data['age'].min()
# Out:
# 19

# %%
bank_data['age'].max()
# Out:
# 87

# %%
bank_data['balance'].min()
# Out:
# -3313

# %% [markdown]
# We see -3313 in the balance, Could be failed to maintain the minimum balance

# %%
bank_data['balance'].max()
# Out:
# 71188

# %%
bank_data['day'].min()
# Out:
# 1

# %%
bank_data['day'].max()
# Out:
# 31

# %%
bank_data['duration'].min()
# Out:
# 4

# %%
bank_data['duration'].max()
# Out:
# 3025

# %%
bank_data['campaign'].min()
# Out:
# 1

# %%
bank_data['campaign'].max()
# Out:
# 50

# %%
bank_data['pdays'].min()
# Out:
# -1

# %% [markdown]
# we see -1 in pdays, It could be an error in data

# %%
bank_data['pdays'].max()
# Out:
# 871

# %%
bank_data['previous'].min()
# Out:
# 0

# %%
bank_data['previous'].max()
# Out:
# 25

# %% [markdown]
# 3.  Can you make a bar plot or a histogram?

# %%
bank_data.hist(figsize=(16, 16), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B41D668>,
# ...
#       dtype=object)

# %% [markdown]
# 4. Can you compare two related quantities?

# %%
df = pd.DataFrame(bank_data, columns = ['age', 'balance',  
                                    'campaign', 'day', 
                                    'duration', 'pdays','previous'] ) 
df
# Out:
#       age  balance  campaign  day  duration  pdays  previous
# 0      30     1787         1   19        79     -1         0
# 1      33     4789         1   11       220    339         4
# 2      35     1350         1   16       185    330         1
# 3      30     1476         4    3       199     -1         0
# 4      59        0         1    5       226     -1         0
# 5      35      747         2   23       141    176         3
# 6      36      307         1   14       341    330         2
# 7      39      147         2    6       151     -1         0
# 8      41      221         2   14        57     -1         0
# 9      43      -88         1   17       313    147         2
# 10     39     9374         1   20       273     -1         0
# 11     43      264         2   17       113     -1         0
# 12     36     1109         2   13       328     -1         0
# 13     20      502         1   30       261     -1         0
# ...

# %%
# Here Comparing two attributes "age" and "balance" using bar plot

# %%
plt.bar(bank_data['age'], bank_data['balance']) 
plt.xlabel("age") 
plt.ylabel("balance") 
plt.show()

# %%
plt.bar(bank_data['education'], bank_data['balance']) 
plt.xlabel("education") 
plt.ylabel("balance") 
plt.show()

# %%
plt.bar(bank_data['balance'], bank_data['job']) 
plt.xlabel("balance") 
plt.ylabel("job") 
plt.show()

# %%
plt.bar(bank_data['campaign'], bank_data['poutcome']) 
plt.xlabel("poutcome") 
plt.ylabel("campaign") 
plt.show()

# %%
plt.bar(bank_data['marital'], bank_data['balance']) 
plt.xlabel("marital") 
plt.ylabel("balance") 
plt.show()

# %%
sns.regplot(data=bank_data,x="age", y="balance",
            fit_reg=False,scatter_kws={'alpha':0.15})

# %%
g = sns.FacetGrid(bank_data, hue="age", palette="Set1", height=5 )
g.map(plt.scatter, "balance", "pdays", s=100, linewidth=.5, edgecolor="white")
g.add_legend();
