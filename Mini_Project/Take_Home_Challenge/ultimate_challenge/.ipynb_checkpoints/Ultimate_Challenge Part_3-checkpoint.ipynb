# %% [markdown]
# # Ultimate_Challenge Part_3

# %%
import json
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

f=open('ultimate_data_challenge.json')
data = json.load(f)
df = pd.DataFrame.from_dict(data, orient='columns')
df
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 1                       5.0       1.00     2014-05-05  Android        0.0
# 2                       4.3       1.00     2014-01-07   iPhone        0.0
# 3                       4.6       1.14     2014-06-29   iPhone       20.0
# 4                       4.4       1.19     2014-03-15  Android       11.8
# ...                     ...        ...            ...      ...        ...
# 49995                   5.0       1.00     2014-06-05   iPhone        0.0
# 49996                   NaN       1.00     2014-01-25   iPhone        0.0
# 49997                   5.0       1.00     2014-05-22  Android        0.0
# 49998                   3.0       1.00     2014-01-15   iPhone        0.0
# 49999                   NaN       1.00     2014-04-20  Android        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver
# 0                     True         46.2      3.67                   5.0
# 1                    False         50.0      8.26                   5.0
# 2                    False        100.0      0.77                   5.0
# 3                     True         80.0      2.36                   4.9
# 4                    False         82.4      3.13                   4.9
# ...                    ...          ...       ...                   ...
# 49995                False        100.0      5.63                   4.2
# 49996                False          0.0      0.00                   4.0
# 49997                 True        100.0      3.86                   5.0
# 49998                False        100.0      4.58                   3.5
# 49999                False          0.0      3.49                   5.0
#
# [50000 rows x 12 columns]

# %%
df['last_trip_date'] = pd.to_datetime(df['last_trip_date'])
df
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 1                       5.0       1.00     2014-05-05  Android        0.0
# 2                       4.3       1.00     2014-01-07   iPhone        0.0
# 3                       4.6       1.14     2014-06-29   iPhone       20.0
# 4                       4.4       1.19     2014-03-15  Android       11.8
# ...                     ...        ...            ...      ...        ...
# 49995                   5.0       1.00     2014-06-05   iPhone        0.0
# 49996                   NaN       1.00     2014-01-25   iPhone        0.0
# 49997                   5.0       1.00     2014-05-22  Android        0.0
# 49998                   3.0       1.00     2014-01-15   iPhone        0.0
# 49999                   NaN       1.00     2014-04-20  Android        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver
# 0                     True         46.2      3.67                   5.0
# 1                    False         50.0      8.26                   5.0
# 2                    False        100.0      0.77                   5.0
# 3                     True         80.0      2.36                   4.9
# 4                    False         82.4      3.13                   4.9
# ...                    ...          ...       ...                   ...
# 49995                False        100.0      5.63                   4.2
# 49996                False          0.0      0.00                   4.0
# 49997                 True        100.0      3.86                   5.0
# 49998                False        100.0      4.58                   3.5
# 49999                False          0.0      3.49                   5.0
#
# [50000 rows x 12 columns]

# %% [markdown]
# I will look at the latest date in the last_trip_date column to estimate when the data was pulled, assuming that someone in the dataset has taken a trip right about when the data was pulled. This is pretty likely given that there are 50,000 rows.

# %%
df_sorted = df.sort_values(by='last_trip_date')
df_sorted
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 31425      Winterfell                       1  2014-01-01
# 10729      Winterfell                       1  2014-01-01
# 40336      Winterfell                       1  2014-01-01
# 34828         Astapor                       1  2014-01-01
# 37295      Winterfell                       1  2014-01-01
# ...               ...                     ...         ...
# 45126      Winterfell                       1  2014-01-10
# 38651  King's Landing                       0  2014-01-13
# 14473  King's Landing                       0  2014-01-02
# 22735      Winterfell                       0  2014-01-08
# 45357         Astapor                       5  2014-01-28
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 31425                   NaN       1.00     2014-01-01   iPhone        0.0
# 10729                   3.0       1.00     2014-01-01   iPhone        0.0
# 40336                   5.0       1.00     2014-01-01   iPhone        0.0
# 34828                   5.0       1.25     2014-01-01   iPhone      100.0
# 37295                   3.0       1.00     2014-01-01   iPhone        0.0
# ...                     ...        ...            ...      ...        ...
# 45126                   4.6       1.02     2014-07-01  Android        6.3
# 38651                   4.9       1.00     2014-07-01   iPhone        0.0
# 14473                   5.0       1.00     2014-07-01  Android        0.0
# 22735                   5.0       1.00     2014-07-01   iPhone        0.0
# 45357                   4.4       1.02     2014-07-01   iPhone        1.4
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver
# 31425                False        100.0      4.31                   5.0
# 10729                False        100.0     19.67                   5.0
# 40336                False        100.0      5.98                   5.0
# 34828                False        100.0      2.45                   5.0
# 37295                False        100.0      0.77                   5.0
# ...                    ...          ...       ...                   ...
# 45126                False         56.3      6.13                   4.6
# 38651                 True         92.3     10.19                   5.0
# 14473                False        100.0      5.06                   5.0
# 22735                 True         75.0      8.71                   5.0
# 45357                False         76.4      3.90                   4.9
#
# [50000 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

plt.hist(df['avg_rating_of_driver'])
plt.show()

# %% [markdown]
# The last trip date is July 1st, 2014, so I will say that the data was pulled on July 1st. June is 30 days long, so I will consider users retained if they took a trip between June 1st and July 1st.

# %%
from datetime import datetime as dt
datetime_june1st = dt.strptime('June 1 2014', '%B %d %Y')

df['retained'] = (df['last_trip_date'] >= datetime_june1st)

# %%
df
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 1                       5.0       1.00     2014-05-05  Android        0.0
# 2                       4.3       1.00     2014-01-07   iPhone        0.0
# 3                       4.6       1.14     2014-06-29   iPhone       20.0
# 4                       4.4       1.19     2014-03-15  Android       11.8
# ...                     ...        ...            ...      ...        ...
# 49995                   5.0       1.00     2014-06-05   iPhone        0.0
# 49996                   NaN       1.00     2014-01-25   iPhone        0.0
# 49997                   5.0       1.00     2014-05-22  Android        0.0
# 49998                   3.0       1.00     2014-01-15   iPhone        0.0
# 49999                   NaN       1.00     2014-04-20  Android        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                     True         46.2      3.67                   5.0
# 1                    False         50.0      8.26                   5.0
# 2                    False        100.0      0.77                   5.0
# 3                     True         80.0      2.36                   4.9
# 4                    False         82.4      3.13                   4.9
# ...                    ...          ...       ...                   ...
# 49995                False        100.0      5.63                   4.2
# 49996                False          0.0      0.00                   4.0
# 49997                 True        100.0      3.86                   5.0
# 49998                False        100.0      4.58                   3.5
# 49999                False          0.0      3.49                   5.0
#
#        retained
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
# ...         ...
# 49995      True
# 49996     False
# 49997     False
# 49998     False
# 49999     False
#
# [50000 rows x 13 columns]

# %%
df['retained'].value_counts()
# Out:
# False    31196
# True     18804
# Name: retained, dtype: int64

# %%
len(df[df['retained'] == True])/(len(df['retained']))
# Out:
# 0.37608

# %% [markdown]
# 37.6% of users were retained, i.e. 37.6% of users had a trip in June.
#
# Drop missing values

# %%
df['avg_rating_of_driver'] = df['avg_rating_of_driver'].fillna(df.avg_rating_of_driver.mean())
df['avg_rating_by_driver'] = df['avg_rating_by_driver'].fillna(df.avg_rating_by_driver.mean())
df = df.dropna()

# %%
df['city'].value_counts()
# Out:
# Winterfell        23125
# Astapor           16413
# King's Landing    10066
# Name: city, dtype: int64

# %%
retained_df = df[df['retained'] == True]
retained_df
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 3      King's Landing                       9  2014-01-10
# 5          Winterfell                       2  2014-01-09
# 13     King's Landing                       0  2014-01-29
# 16     King's Landing                       1  2014-01-11
# ...               ...                     ...         ...
# 49976  King's Landing                       0  2014-01-21
# 49988  King's Landing                       1  2014-01-20
# 49991      Winterfell                       0  2014-01-08
# 49993         Astapor                       3  2014-01-03
# 49995  King's Landing                       0  2014-01-25
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 3                       4.6       1.14     2014-06-29   iPhone       20.0
# 5                       3.5       1.00     2014-06-06   iPhone        0.0
# 13                      4.0       1.38     2014-06-08   iPhone       50.0
# 16                      5.0       1.00     2014-06-28  Android        0.0
# ...                     ...        ...            ...      ...        ...
# 49976                   2.0       1.00     2014-07-01   iPhone        0.0
# 49988                   4.5       1.00     2014-06-14   iPhone        0.0
# 49991                   5.0       1.25     2014-06-29   iPhone      100.0
# 49993                   4.8       1.11     2014-07-01   iPhone       11.1
# 49995                   5.0       1.00     2014-06-05   iPhone        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                     True         46.2      3.67                   5.0
# 3                     True         80.0      2.36                   4.9
# 5                     True        100.0     10.56                   5.0
# 13                   False         50.0      3.04                   5.0
# 16                    True         50.0     10.86                   3.0
# ...                    ...          ...       ...                   ...
# 49976                False        100.0      2.39                   4.0
# 49988                False         50.0      2.53                   5.0
# 49991                False          0.0      1.06                   5.0
# 49993                 True         55.6      2.53                   4.7
# 49995                False        100.0      5.63                   4.2
#
#        retained
# 0          True
# 3          True
# 5          True
# 13         True
# 16         True
# ...         ...
# 49976      True
# 49988      True
# 49991      True
# 49993      True
# 49995      True
#
# [18671 rows x 13 columns]

# %%
retained_df.shape
# Out:
# (18671, 13)

# %%
notretained_df = df[df['retained'] == False]
notretained_df.shape
# Out:
# (30933, 13)

# %%
avg_rating_by_driver_retained = retained_df['avg_rating_by_driver'].mean()
avg_rating_by_driver_retained
# Out:
# 4.762739740509591

# %%
avg_rating_by_driver_notretained = notretained_df['avg_rating_by_driver'].mean()
avg_rating_by_driver_notretained
# Out:
# 4.786989998633896

# %%
from scipy import stats
stats.ttest_ind(retained_df['avg_rating_by_driver'], notretained_df['avg_rating_by_driver'])
# Out:
# Ttest_indResult(statistic=-5.866102189191887, pvalue=4.489821762285149e-09)

# %% [markdown]
# The average ratings by driver are significantly different between retained and not retained customers, with the average rating by driver for retained customers being 4.763 and the average rating by driver for not retained customers being 4.787.

# %%
avg_rating_of_driver_retained = retained_df['avg_rating_of_driver'].mean()
avg_rating_of_driver_retained
# Out:
# 4.593778007093732

# %%
avg_rating_of_driver_notretained = notretained_df['avg_rating_of_driver'].mean()
avg_rating_of_driver_notretained
# Out:
# 4.606132146940676

# %%
stats.ttest_ind(retained_df['avg_rating_of_driver'], notretained_df['avg_rating_of_driver'])
# Out:
# Ttest_indResult(statistic=-2.358553233835392, pvalue=0.018350184675161908)

# %% [markdown]
# Significant at level of p<0.05, but not as significant as average rating by driver.
#
# Going to look at city and whether someone was an Ultimate Black User.

# %%
# set width of bar
barWidth = 0.25

values_retained = retained_df['ultimate_black_user'].value_counts().keys().tolist()
counts_retained = retained_df['ultimate_black_user'].value_counts().tolist()
value_dict_retained = dict(zip(values_retained, counts_retained))

values_notretained = notretained_df['ultimate_black_user'].value_counts().keys().tolist()
counts_notretained = notretained_df['ultimate_black_user'].value_counts().tolist()
value_dict_notretained = dict(zip(values_notretained, counts_notretained))

bars1 = [value_dict_retained[True], value_dict_retained[False]]
bars2 = [value_dict_notretained[True], value_dict_notretained[False]]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#b5ffb9', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#f9bc86', width=barWidth, edgecolor='white', label='var2')
 
# Add xticks on the middle of the group bars
plt.xticks([r + barWidth for r in range(len(bars1))], ['Ultimate Black User', 'Not Ultimate Black User'])
plt.ylabel('Count')
 
# Create legend & Show graphic
plt.legend(['Retained', 'Not retained'])
plt.title('Ultimate Black User')
plt.show()

# %%
# set width of bar
barWidth = 0.25

values_retained = retained_df['city'].value_counts().keys().tolist()
counts_retained = retained_df['city'].value_counts().tolist()
value_dict_retained = dict(zip(values_retained, counts_retained))

values_notretained = notretained_df['city'].value_counts().keys().tolist()
counts_notretained = notretained_df['city'].value_counts().tolist()
value_dict_notretained = dict(zip(values_notretained, counts_notretained))

bars1 = [value_dict_retained['Winterfell'], value_dict_retained['Astapor'], value_dict_retained["King's Landing"]]
bars2 = [value_dict_notretained['Winterfell'], value_dict_notretained['Astapor'], 
         value_dict_notretained["King's Landing"]]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#b5ffb9', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#f9bc86', width=barWidth, edgecolor='white', label='var2')
 
# Add xticks on the middle of the group bars
plt.xticks([r + barWidth for r in range(len(bars1))], ['Winterfell', 'Astapor', "King's Landing"])
plt.ylabel('Count')
 
# Create legend & Show graphic
plt.legend(['Retained', 'Not retained'])
plt.title('City distributions')
plt.show()

# %%
df['phone'].value_counts()
# Out:
# iPhone     34582
# Android    15022
# Name: phone, dtype: int64

# %% [markdown]
# For predictive model, I want to predict whether user was retained (had a June trip) based on the other columns in the model. I will not include the last_trip_date column since I only want to predict whether someone had a June trip or not. However, I will include signup_date because it is possible that users who signed up later in January might be more likely to have a trip in June. The other columns should all be predictive as well.
#
# I will have to convert the city and phone columns to numeric oolumns using pd.get_dummies.

# %%
df_no_last_trip_date = df.drop('last_trip_date', axis=1)

# %%
df_no_last_trip_date
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge    phone  surge_pct  \
# 0                  4.700000       1.10   iPhone       15.4
# 1                  5.000000       1.00  Android        0.0
# 2                  4.300000       1.00   iPhone        0.0
# 3                  4.600000       1.14   iPhone       20.0
# 4                  4.400000       1.19  Android       11.8
# ...                     ...        ...      ...        ...
# 49995              5.000000       1.00   iPhone        0.0
# 49996              4.601559       1.00   iPhone        0.0
# 49997              5.000000       1.00  Android        0.0
# 49998              3.000000       1.00   iPhone        0.0
# 49999              4.601559       1.00  Android        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                     True         46.2      3.67                   5.0
# 1                    False         50.0      8.26                   5.0
# 2                    False        100.0      0.77                   5.0
# 3                     True         80.0      2.36                   4.9
# 4                    False         82.4      3.13                   4.9
# ...                    ...          ...       ...                   ...
# 49995                False        100.0      5.63                   4.2
# 49996                False          0.0      0.00                   4.0
# 49997                 True        100.0      3.86                   5.0
# 49998                False        100.0      4.58                   3.5
# 49999                False          0.0      3.49                   5.0
#
#        retained
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
# ...         ...
# 49995      True
# 49996     False
# 49997     False
# 49998     False
# 49999     False
#
# [49604 rows x 12 columns]

# %%
df_no_last_trip_date['signup_date'] = pd.to_datetime(df_no_last_trip_date['signup_date'])
df_no_last_trip_date['signup_day'] = pd.DatetimeIndex(df_no_last_trip_date['signup_date']).day
df_no_last_trip_date
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge    phone  surge_pct  \
# 0                  4.700000       1.10   iPhone       15.4
# 1                  5.000000       1.00  Android        0.0
# 2                  4.300000       1.00   iPhone        0.0
# 3                  4.600000       1.14   iPhone       20.0
# 4                  4.400000       1.19  Android       11.8
# ...                     ...        ...      ...        ...
# 49995              5.000000       1.00   iPhone        0.0
# 49996              4.601559       1.00   iPhone        0.0
# 49997              5.000000       1.00  Android        0.0
# 49998              3.000000       1.00   iPhone        0.0
# 49999              4.601559       1.00  Android        0.0
#
#        ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                     True         46.2      3.67                   5.0
# 1                    False         50.0      8.26                   5.0
# 2                    False        100.0      0.77                   5.0
# 3                     True         80.0      2.36                   4.9
# 4                    False         82.4      3.13                   4.9
# ...                    ...          ...       ...                   ...
# 49995                False        100.0      5.63                   4.2
# 49996                False          0.0      0.00                   4.0
# 49997                 True        100.0      3.86                   5.0
# 49998                False        100.0      4.58                   3.5
# 49999                False          0.0      3.49                   5.0
#
#        retained  signup_day
# 0          True          25
# 1         False          29
# 2         False           6
# 3          True          10
# 4         False          27
# ...         ...         ...
# 49995      True          25
# 49996     False          24
# 49997     False          31
# 49998     False          14
# 49999     False          18
#
# [49604 rows x 13 columns]

# %%
df_no_last_trip_date['ultimate_black_user'] = df_no_last_trip_date['ultimate_black_user'].astype(int)

# %%
df_no_last_trip_date['retained'] = df_no_last_trip_date['retained'].astype(int)

# %%
df_no_last_trip_date_2 = df_no_last_trip_date.drop('signup_date', axis=1)
df_no_last_trip_date_2
# Out:
#                  city  trips_in_first_30_days  avg_rating_of_driver  \
# 0      King's Landing                       4              4.700000
# 1             Astapor                       0              5.000000
# 2             Astapor                       3              4.300000
# 3      King's Landing                       9              4.600000
# 4          Winterfell                      14              4.400000
# ...               ...                     ...                   ...
# 49995  King's Landing                       0              5.000000
# 49996         Astapor                       1              4.601559
# 49997      Winterfell                       0              5.000000
# 49998         Astapor                       2              3.000000
# 49999         Astapor                       0              4.601559
#
#        avg_surge    phone  surge_pct  ultimate_black_user  weekday_pct  \
# 0           1.10   iPhone       15.4                    1         46.2
# 1           1.00  Android        0.0                    0         50.0
# 2           1.00   iPhone        0.0                    0        100.0
# 3           1.14   iPhone       20.0                    1         80.0
# 4           1.19  Android       11.8                    0         82.4
# ...          ...      ...        ...                  ...          ...
# 49995       1.00   iPhone        0.0                    0        100.0
# 49996       1.00   iPhone        0.0                    0          0.0
# 49997       1.00  Android        0.0                    1        100.0
# 49998       1.00   iPhone        0.0                    0        100.0
# 49999       1.00  Android        0.0                    0          0.0
#
#        avg_dist  avg_rating_by_driver  retained  signup_day
# 0          3.67                   5.0         1          25
# 1          8.26                   5.0         0          29
# 2          0.77                   5.0         0           6
# 3          2.36                   4.9         1          10
# 4          3.13                   4.9         0          27
# ...         ...                   ...       ...         ...
# 49995      5.63                   4.2         1          25
# 49996      0.00                   4.0         0          24
# 49997      3.86                   5.0         0          31
# 49998      4.58                   3.5         0          14
# 49999      3.49                   5.0         0          18
#
# [49604 rows x 12 columns]

# %%
X = df_no_last_trip_date_2.drop('retained', axis=1)
y = df_no_last_trip_date_2['retained']

# %%
X
# Out:
#                  city  trips_in_first_30_days  avg_rating_of_driver  \
# 0      King's Landing                       4              4.700000
# 1             Astapor                       0              5.000000
# 2             Astapor                       3              4.300000
# 3      King's Landing                       9              4.600000
# 4          Winterfell                      14              4.400000
# ...               ...                     ...                   ...
# 49995  King's Landing                       0              5.000000
# 49996         Astapor                       1              4.601559
# 49997      Winterfell                       0              5.000000
# 49998         Astapor                       2              3.000000
# 49999         Astapor                       0              4.601559
#
#        avg_surge    phone  surge_pct  ultimate_black_user  weekday_pct  \
# 0           1.10   iPhone       15.4                    1         46.2
# 1           1.00  Android        0.0                    0         50.0
# 2           1.00   iPhone        0.0                    0        100.0
# 3           1.14   iPhone       20.0                    1         80.0
# 4           1.19  Android       11.8                    0         82.4
# ...          ...      ...        ...                  ...          ...
# 49995       1.00   iPhone        0.0                    0        100.0
# 49996       1.00   iPhone        0.0                    0          0.0
# 49997       1.00  Android        0.0                    1        100.0
# 49998       1.00   iPhone        0.0                    0        100.0
# 49999       1.00  Android        0.0                    0          0.0
#
#        avg_dist  avg_rating_by_driver  signup_day
# 0          3.67                   5.0          25
# 1          8.26                   5.0          29
# 2          0.77                   5.0           6
# 3          2.36                   4.9          10
# 4          3.13                   4.9          27
# ...         ...                   ...         ...
# 49995      5.63                   4.2          25
# 49996      0.00                   4.0          24
# 49997      3.86                   5.0          31
# 49998      4.58                   3.5          14
# 49999      3.49                   5.0          18
#
# [49604 rows x 11 columns]

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: retained, Length: 49604, dtype: int32

# %%
X_dummies = pd.get_dummies(X, drop_first=True)
X_dummies.columns
# Out:
# Index(['trips_in_first_30_days', 'avg_rating_of_driver', 'avg_surge',
#        'surge_pct', 'ultimate_black_user', 'weekday_pct', 'avg_dist',
#        'avg_rating_by_driver', 'signup_day', 'city_King's Landing',
#        'city_Winterfell', 'phone_iPhone'],
#       dtype='object')

# %% [markdown]
# Since the data is unbalanced, it might be useful to use the class balanced parameter. I will try logistic regression, random forests, and SVM.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import recall_score

c_space = np.logspace(-5,8,15)
param_grid = {'C':c_space, 'penalty':['l1','l2']}

X_train, X_test, y_train, y_test= train_test_split(X_dummies, y, test_size=0.3, random_state=42)

logreg_classbalanced = LogisticRegression(class_weight='balanced')

logreg_cv_class_balanced = GridSearchCV(logreg_classbalanced, param_grid, cv=5, scoring='f1')
logreg_cv_class_balanced.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(class_weight='balanced'),
#              param_grid={'C': array([1.00000000e-05, 8.48342898e-05, 7.19685673e-04, 6.10540230e-03,
#        5.17947468e-02, 4.39397056e-01, 3.72759372e+00, 3.16227766e+01,
#        2.68269580e+02, 2.27584593e+03, 1.93069773e+04, 1.63789371e+05,
#        1.38949549e+06, 1.17876863e+07, 1.00000000e+08]),
#                          'penalty': ['l1', 'l2']},
#              scoring='f1')

# %%
y_pred1 = logreg_cv_class_balanced.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75      9320
#            1       0.58      0.67      0.62      5562
#
#     accuracy                           0.70     14882
#    macro avg       0.68      0.69      0.69     14882
# weighted avg       0.71      0.70      0.70     14882

# %% [markdown]
# Trying random forests

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

param_grid_rfc = { 
    'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
    'max_features': ['auto', 'sqrt', 'log2']
}

rfc = RandomForestClassifier(random_state=42, class_weight='balanced')
rfc_cv = GridSearchCV(rfc, param_grid_rfc, cv=5, scoring='f1', verbose=2)
rfc_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] max_features=auto, n_estimators=200 .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .............. max_features=auto, n_estimators=200, total=  21.3s
# [CV] max_features=auto, n_estimators=200 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   21.3s remaining:    0.0s
# [CV] .............. max_features=auto, n_estimators=200, total=  14.2s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] .............. max_features=auto, n_estimators=200, total=  13.3s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] .............. max_features=auto, n_estimators=200, total=  12.7s
# [CV] max_features=auto, n_estimators=200 .............................
# [CV] .............. max_features=auto, n_estimators=200, total=  12.6s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] .............. max_features=auto, n_estimators=400, total=  25.2s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] .............. max_features=auto, n_estimators=400, total=  33.4s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] .............. max_features=auto, n_estimators=400, total=  32.9s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] .............. max_features=auto, n_estimators=400, total=  27.6s
# [CV] max_features=auto, n_estimators=400 .............................
# [CV] .............. max_features=auto, n_estimators=400, total=  23.9s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] .............. max_features=auto, n_estimators=600, total=  37.8s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] .............. max_features=auto, n_estimators=600, total=  46.3s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] .............. max_features=auto, n_estimators=600, total=  52.5s
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] .............. max_features=auto, n_estimators=600, total= 1.0min
# [CV] max_features=auto, n_estimators=600 .............................
# [CV] .............. max_features=auto, n_estimators=600, total= 1.1min
# [CV] max_features=auto, n_estimators=800 .............................
# [CV] .............. max_features=auto, n_estimators=800, total= 1.5min
# [CV] max_features=auto, n_estimators=800 .............................
# [CV] .............. max_features=auto, n_estimators=800, total= 1.4min
# [CV] max_features=auto, n_estimators=800 .............................
# [CV] .............. max_features=auto, n_estimators=800, total= 1.5min
# [CV] max_features=auto, n_estimators=800 .............................
# [CV] .............. max_features=auto, n_estimators=800, total= 1.5min
# [CV] max_features=auto, n_estimators=800 .............................
# [CV] .............. max_features=auto, n_estimators=800, total= 1.6min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 1.7min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 1.9min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 1.7min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 1.8min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 1.8min
# [CV] max_features=auto, n_estimators=1200 ............................
# [CV] ............. max_features=auto, n_estimators=1200, total= 1.9min
# [CV] max_features=auto, n_estimators=1200 ............................
# [CV] ............. max_features=auto, n_estimators=1200, total= 1.7min
# [CV] max_features=auto, n_estimators=1200 ............................
# [CV] ............. max_features=auto, n_estimators=1200, total= 1.7min
# [CV] max_features=auto, n_estimators=1200 ............................
# [CV] ............. max_features=auto, n_estimators=1200, total= 1.7min
# [CV] max_features=auto, n_estimators=1200 ............................
# [CV] ............. max_features=auto, n_estimators=1200, total= 1.6min
# [CV] max_features=auto, n_estimators=1400 ............................
# [CV] ............. max_features=auto, n_estimators=1400, total= 2.1min
# [CV] max_features=auto, n_estimators=1400 ............................
# [CV] ............. max_features=auto, n_estimators=1400, total= 1.8min
# [CV] max_features=auto, n_estimators=1400 ............................
# [CV] ............. max_features=auto, n_estimators=1400, total= 1.9min
# [CV] max_features=auto, n_estimators=1400 ............................
# [CV] ............. max_features=auto, n_estimators=1400, total= 2.0min
# [CV] max_features=auto, n_estimators=1400 ............................
# [CV] ............. max_features=auto, n_estimators=1400, total= 2.1min
# [CV] max_features=auto, n_estimators=1600 ............................
# [CV] ............. max_features=auto, n_estimators=1600, total= 2.3min
# [CV] max_features=auto, n_estimators=1600 ............................
# [CV] ............. max_features=auto, n_estimators=1600, total= 2.5min
# [CV] max_features=auto, n_estimators=1600 ............................
# [CV] ............. max_features=auto, n_estimators=1600, total= 2.4min
# [CV] max_features=auto, n_estimators=1600 ............................
# [CV] ............. max_features=auto, n_estimators=1600, total= 2.4min
# [CV] max_features=auto, n_estimators=1600 ............................
# [CV] ............. max_features=auto, n_estimators=1600, total= 2.4min
# [CV] max_features=auto, n_estimators=1800 ............................
# [CV] ............. max_features=auto, n_estimators=1800, total= 2.8min
# [CV] max_features=auto, n_estimators=1800 ............................
# [CV] ............. max_features=auto, n_estimators=1800, total= 2.7min
# [CV] max_features=auto, n_estimators=1800 ............................
# [CV] ............. max_features=auto, n_estimators=1800, total= 2.7min
# [CV] max_features=auto, n_estimators=1800 ............................
# [CV] ............. max_features=auto, n_estimators=1800, total= 3.1min
# [CV] max_features=auto, n_estimators=1800 ............................
# [CV] ............. max_features=auto, n_estimators=1800, total= 2.9min
# [CV] max_features=auto, n_estimators=2000 ............................
# [CV] ............. max_features=auto, n_estimators=2000, total= 2.9min
# [CV] max_features=auto, n_estimators=2000 ............................
# [CV] ............. max_features=auto, n_estimators=2000, total= 2.8min
# [CV] max_features=auto, n_estimators=2000 ............................
# [CV] ............. max_features=auto, n_estimators=2000, total= 3.0min
# [CV] max_features=auto, n_estimators=2000 ............................
# [CV] ............. max_features=auto, n_estimators=2000, total= 3.0min
# [CV] max_features=auto, n_estimators=2000 ............................
# [CV] ............. max_features=auto, n_estimators=2000, total= 3.5min
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] .............. max_features=sqrt, n_estimators=200, total=  20.8s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] .............. max_features=sqrt, n_estimators=200, total=  21.0s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] .............. max_features=sqrt, n_estimators=200, total=  12.2s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] .............. max_features=sqrt, n_estimators=200, total=  21.3s
# [CV] max_features=sqrt, n_estimators=200 .............................
# [CV] .............. max_features=sqrt, n_estimators=200, total=  20.9s
# [CV] max_features=sqrt, n_estimators=400 .............................
# [CV] .............. max_features=sqrt, n_estimators=400, total=  41.2s
# [CV] max_features=sqrt, n_estimators=400 .............................
# [CV] .............. max_features=sqrt, n_estimators=400, total=  44.1s
# [CV] max_features=sqrt, n_estimators=400 .............................
# [CV] .............. max_features=sqrt, n_estimators=400, total=  43.8s
# [CV] max_features=sqrt, n_estimators=400 .............................
# [CV] .............. max_features=sqrt, n_estimators=400, total=  43.1s
# [CV] max_features=sqrt, n_estimators=400 .............................
# [CV] .............. max_features=sqrt, n_estimators=400, total=  45.4s
# [CV] max_features=sqrt, n_estimators=600 .............................
# [CV] .............. max_features=sqrt, n_estimators=600, total= 1.1min
# [CV] max_features=sqrt, n_estimators=600 .............................
# [CV] .............. max_features=sqrt, n_estimators=600, total= 1.0min
# [CV] max_features=sqrt, n_estimators=600 .............................
# [CV] .............. max_features=sqrt, n_estimators=600, total=  58.5s
# [CV] max_features=sqrt, n_estimators=600 .............................
# [CV] .............. max_features=sqrt, n_estimators=600, total=  54.3s
# [CV] max_features=sqrt, n_estimators=600 .............................
# [CV] .............. max_features=sqrt, n_estimators=600, total=  45.1s
# [CV] max_features=sqrt, n_estimators=800 .............................
# [CV] .............. max_features=sqrt, n_estimators=800, total= 1.4min
# [CV] max_features=sqrt, n_estimators=800 .............................
# [CV] .............. max_features=sqrt, n_estimators=800, total= 1.1min
# [CV] max_features=sqrt, n_estimators=800 .............................
# [CV] .............. max_features=sqrt, n_estimators=800, total=  54.4s
# [CV] max_features=sqrt, n_estimators=800 .............................
# [CV] .............. max_features=sqrt, n_estimators=800, total= 1.2min
# [CV] max_features=sqrt, n_estimators=800 .............................
# [CV] .............. max_features=sqrt, n_estimators=800, total=  58.5s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total=  58.3s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 1.3min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 1.3min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 1.4min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 1.7min
# [CV] max_features=sqrt, n_estimators=1200 ............................
# [CV] ............. max_features=sqrt, n_estimators=1200, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1200 ............................
# [CV] ............. max_features=sqrt, n_estimators=1200, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1200 ............................
# [CV] ............. max_features=sqrt, n_estimators=1200, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1200 ............................
# [CV] ............. max_features=sqrt, n_estimators=1200, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1200 ............................
# [CV] ............. max_features=sqrt, n_estimators=1200, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1400 ............................
# [CV] ............. max_features=sqrt, n_estimators=1400, total= 2.3min
# [CV] max_features=sqrt, n_estimators=1400 ............................
# [CV] ............. max_features=sqrt, n_estimators=1400, total= 2.6min
# [CV] max_features=sqrt, n_estimators=1400 ............................
# [CV] ............. max_features=sqrt, n_estimators=1400, total= 2.6min
# [CV] max_features=sqrt, n_estimators=1400 ............................
# [CV] ............. max_features=sqrt, n_estimators=1400, total= 2.6min
# [CV] max_features=sqrt, n_estimators=1400 ............................
# [CV] ............. max_features=sqrt, n_estimators=1400, total= 2.5min
# [CV] max_features=sqrt, n_estimators=1600 ............................
# [CV] ............. max_features=sqrt, n_estimators=1600, total= 2.9min
# [CV] max_features=sqrt, n_estimators=1600 ............................
# [CV] ............. max_features=sqrt, n_estimators=1600, total= 2.5min
# [CV] max_features=sqrt, n_estimators=1600 ............................
# [CV] ............. max_features=sqrt, n_estimators=1600, total= 3.0min
# [CV] max_features=sqrt, n_estimators=1600 ............................
# [CV] ............. max_features=sqrt, n_estimators=1600, total= 2.6min
# [CV] max_features=sqrt, n_estimators=1600 ............................
# [CV] ............. max_features=sqrt, n_estimators=1600, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1800 ............................
# [CV] ............. max_features=sqrt, n_estimators=1800, total= 3.2min
# [CV] max_features=sqrt, n_estimators=1800 ............................
# [CV] ............. max_features=sqrt, n_estimators=1800, total= 3.3min
# [CV] max_features=sqrt, n_estimators=1800 ............................
# [CV] ............. max_features=sqrt, n_estimators=1800, total= 3.3min
# [CV] max_features=sqrt, n_estimators=1800 ............................
# [CV] ............. max_features=sqrt, n_estimators=1800, total= 3.2min
# [CV] max_features=sqrt, n_estimators=1800 ............................
# [CV] ............. max_features=sqrt, n_estimators=1800, total= 3.1min
# [CV] max_features=sqrt, n_estimators=2000 ............................
# [CV] ............. max_features=sqrt, n_estimators=2000, total= 3.1min
# [CV] max_features=sqrt, n_estimators=2000 ............................
# [CV] ............. max_features=sqrt, n_estimators=2000, total= 3.5min
# [CV] max_features=sqrt, n_estimators=2000 ............................
# [CV] ............. max_features=sqrt, n_estimators=2000, total= 3.5min
# [CV] max_features=sqrt, n_estimators=2000 ............................
# [CV] ............. max_features=sqrt, n_estimators=2000, total= 3.1min
# [CV] max_features=sqrt, n_estimators=2000 ............................
# [CV] ............. max_features=sqrt, n_estimators=2000, total= 3.5min
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] .............. max_features=log2, n_estimators=200, total=  20.6s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] .............. max_features=log2, n_estimators=200, total=  19.9s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] .............. max_features=log2, n_estimators=200, total=  19.7s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] .............. max_features=log2, n_estimators=200, total=  16.4s
# [CV] max_features=log2, n_estimators=200 .............................
# [CV] .............. max_features=log2, n_estimators=200, total=  16.7s
# [CV] max_features=log2, n_estimators=400 .............................
# [CV] .............. max_features=log2, n_estimators=400, total=  36.6s
# [CV] max_features=log2, n_estimators=400 .............................
# [CV] .............. max_features=log2, n_estimators=400, total=  34.4s
# [CV] max_features=log2, n_estimators=400 .............................
# [CV] .............. max_features=log2, n_estimators=400, total=  38.0s
# [CV] max_features=log2, n_estimators=400 .............................
# [CV] .............. max_features=log2, n_estimators=400, total=  36.5s
# [CV] max_features=log2, n_estimators=400 .............................
# [CV] .............. max_features=log2, n_estimators=400, total=  33.6s
# [CV] max_features=log2, n_estimators=600 .............................
# [CV] .............. max_features=log2, n_estimators=600, total=  49.8s
# [CV] max_features=log2, n_estimators=600 .............................
# [CV] .............. max_features=log2, n_estimators=600, total=  48.2s
# [CV] max_features=log2, n_estimators=600 .............................
# [CV] .............. max_features=log2, n_estimators=600, total=  50.4s
# [CV] max_features=log2, n_estimators=600 .............................
# [CV] .............. max_features=log2, n_estimators=600, total=  49.0s
# [CV] max_features=log2, n_estimators=600 .............................
# [CV] .............. max_features=log2, n_estimators=600, total=  54.1s
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] .............. max_features=log2, n_estimators=800, total= 1.1min
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] .............. max_features=log2, n_estimators=800, total= 1.1min
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] .............. max_features=log2, n_estimators=800, total= 1.2min
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] .............. max_features=log2, n_estimators=800, total= 1.2min
# [CV] max_features=log2, n_estimators=800 .............................
# [CV] .............. max_features=log2, n_estimators=800, total= 1.1min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.4min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] max_features=log2, n_estimators=1200 ............................
# [CV] ............. max_features=log2, n_estimators=1200, total= 1.8min
# [CV] max_features=log2, n_estimators=1200 ............................
# [CV] ............. max_features=log2, n_estimators=1200, total= 1.7min
# [CV] max_features=log2, n_estimators=1200 ............................
# [CV] ............. max_features=log2, n_estimators=1200, total= 1.7min
# [CV] max_features=log2, n_estimators=1200 ............................
# [CV] ............. max_features=log2, n_estimators=1200, total= 1.9min
# [CV] max_features=log2, n_estimators=1200 ............................
# [CV] ............. max_features=log2, n_estimators=1200, total= 1.8min
# [CV] max_features=log2, n_estimators=1400 ............................
# [CV] ............. max_features=log2, n_estimators=1400, total= 2.0min
# [CV] max_features=log2, n_estimators=1400 ............................
# [CV] ............. max_features=log2, n_estimators=1400, total= 1.9min
# [CV] max_features=log2, n_estimators=1400 ............................
# [CV] ............. max_features=log2, n_estimators=1400, total= 2.0min
# [CV] max_features=log2, n_estimators=1400 ............................
# [CV] ............. max_features=log2, n_estimators=1400, total= 2.0min
# [CV] max_features=log2, n_estimators=1400 ............................
# [CV] ............. max_features=log2, n_estimators=1400, total= 2.0min
# [CV] max_features=log2, n_estimators=1600 ............................
# [CV] ............. max_features=log2, n_estimators=1600, total= 2.3min
# [CV] max_features=log2, n_estimators=1600 ............................
# [CV] ............. max_features=log2, n_estimators=1600, total= 2.2min
# [CV] max_features=log2, n_estimators=1600 ............................
# [CV] ............. max_features=log2, n_estimators=1600, total= 2.2min
# [CV] max_features=log2, n_estimators=1600 ............................
# [CV] ............. max_features=log2, n_estimators=1600, total= 2.4min
# [CV] max_features=log2, n_estimators=1600 ............................
# [CV] ............. max_features=log2, n_estimators=1600, total= 2.3min
# [CV] max_features=log2, n_estimators=1800 ............................
# [CV] ............. max_features=log2, n_estimators=1800, total= 2.5min
# [CV] max_features=log2, n_estimators=1800 ............................
# [CV] ............. max_features=log2, n_estimators=1800, total= 2.5min
# [CV] max_features=log2, n_estimators=1800 ............................
# [CV] ............. max_features=log2, n_estimators=1800, total= 2.5min
# [CV] max_features=log2, n_estimators=1800 ............................
# [CV] ............. max_features=log2, n_estimators=1800, total= 2.7min
# [CV] max_features=log2, n_estimators=1800 ............................
# [CV] ............. max_features=log2, n_estimators=1800, total= 2.7min
# [CV] max_features=log2, n_estimators=2000 ............................
# [CV] ............. max_features=log2, n_estimators=2000, total= 3.0min
# [CV] max_features=log2, n_estimators=2000 ............................
# [CV] ............. max_features=log2, n_estimators=2000, total= 2.8min
# [CV] max_features=log2, n_estimators=2000 ............................
# [CV] ............. max_features=log2, n_estimators=2000, total= 2.9min
# [CV] max_features=log2, n_estimators=2000 ............................
# [CV] ............. max_features=log2, n_estimators=2000, total= 3.1min
# [CV] max_features=log2, n_estimators=2000 ............................
# [CV] ............. max_features=log2, n_estimators=2000, total= 2.8min
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 256.6min finished
# Wall time: 4h 17min 43s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400,
#                                           1600, 1800, 2000]},
#              scoring='f1', verbose=2)

# %%
y_pred2 = rfc_cv.predict(X_test)

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83      9320
#            1       0.72      0.65      0.69      5562
#
#     accuracy                           0.78     14882
#    macro avg       0.76      0.75      0.76     14882
# weighted avg       0.77      0.78      0.77     14882

# %%
from sklearn.tree import DecisionTreeClassifier
dtree1 = DecisionTreeClassifier(max_depth=3, random_state=42, class_weight='balanced')
dtree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=3, random_state=42)

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree1, out_file=dot_data, filled=True,
                feature_names = X_train.columns, class_names=['Not retained', 'Retained'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# It looks like the average rating by the driver and whether the city was King's Landing are the two most important factors. If the average rating by the driver was less than 4.05 then that group of riders was not retained. Also, if the city is King's Landing, then that group of riders was retained, and the riders who were not from King's Landing were not retained as much.
