# %%
#Part 1: Exploratory data analysis
#logins.json

# %%
#import json
import json
import pandas as pd

f = open('logins.json')
data = json.load(f)
df = pd.DataFrame.from_dict(data, orient='columns')
df
# Out:
#                 login_time
# 0      1970-01-01 20:13:18
# 1      1970-01-01 20:16:10
# 2      1970-01-01 20:16:37
# 3      1970-01-01 20:16:36
# 4      1970-01-01 20:26:21
# ...                    ...
# 93137  1970-04-13 18:50:19
# 93138  1970-04-13 18:43:56
# 93139  1970-04-13 18:54:02
# 93140  1970-04-13 18:57:38
# 93141  1970-04-13 18:54:23
#
# [93142 rows x 1 columns]

# %%
df.tail()
# Out:
#                 login_time
# 93137  1970-04-13 18:50:19
# 93138  1970-04-13 18:43:56
# 93139  1970-04-13 18:54:02
# 93140  1970-04-13 18:57:38
# 93141  1970-04-13 18:54:23

# %% [markdown]
# It looks like the data ranges from January 1st, 1970 to April 13th, 1970 and has 93,142 data points.

# %%
df['login_time'].isnull().values.any()
# Out:
# False

# %% [markdown]
# There are no missing values. However, it looks like the timestamps are out of order, which may be a problem. I will see if I can put them in order.

# %%
df['count'] = 1
df['login_time'] = pd.to_datetime(df['login_time'])
df_sorted = df.sort_values(by='login_time')
df_sorted
# Out:
#                login_time  count
# 6     1970-01-01 20:12:16      1
# 0     1970-01-01 20:13:18      1
# 1     1970-01-01 20:16:10      1
# 3     1970-01-01 20:16:36      1
# 2     1970-01-01 20:16:37      1
# ...                   ...    ...
# 93136 1970-04-13 18:48:52      1
# 93137 1970-04-13 18:50:19      1
# 93139 1970-04-13 18:54:02      1
# 93141 1970-04-13 18:54:23      1
# 93140 1970-04-13 18:57:38      1
#
# [93142 rows x 2 columns]

# %%
df_sums = df_sorted.set_index('login_time').resample('15T').sum()
df_sums
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# ...                    ...
# 1970-04-13 17:45:00      5
# 1970-04-13 18:00:00      5
# 1970-04-13 18:15:00      2
# 1970-04-13 18:30:00      7
# 1970-04-13 18:45:00      6
#
# [9788 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df_sums.plot(figsize=(15,4))
plt.show()

# %% [markdown]
# This is a plot of the data in 15 minute intervals. I will now try and resample the data to look at it over 1 day intervals which might give me more insight.

# %%
df_oneday = df_sorted.set_index('login_time').resample('1D').sum()
df_oneday.plot(figsize=(15,4))
plt.show()

# %% [markdown]
# It looks like the average count of login times goes up between January and April, but there are fluctuations between days, with about 4-5 peaks per month.

# %%
df_oneday
# Out:
#             count
# login_time
# 1970-01-01    112
# 1970-01-02    681
# 1970-01-03    793
# 1970-01-04    788
# 1970-01-05    459
# ...           ...
# 1970-04-09    818
# 1970-04-10   1009
# 1970-04-11   1352
# 1970-04-12   1409
# 1970-04-13    395
#
# [103 rows x 1 columns]

# %% [markdown]
# I will now look at the first five days of the dataframe, sampled at 1 hour intervals, to give me some idea of the daily fluctuations.

# %%
df_twohours = df_sorted.set_index('login_time').resample('2H').sum()
df_twohours_firstfivedays = df_twohours.first('5D')
df_twohours_firstfivedays
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00     33
# 1970-01-01 22:00:00     79
# 1970-01-02 00:00:00     86
# 1970-01-02 02:00:00     71
# 1970-01-02 04:00:00     20
# 1970-01-02 06:00:00     13
# 1970-01-02 08:00:00     20
# 1970-01-02 10:00:00     81
# 1970-01-02 12:00:00     74
# 1970-01-02 14:00:00     41
# 1970-01-02 16:00:00     36
# 1970-01-02 18:00:00     34
# 1970-01-02 20:00:00     83
# 1970-01-02 22:00:00    122
# 1970-01-03 00:00:00     93
# 1970-01-03 02:00:00    140
# 1970-01-03 04:00:00    110
# 1970-01-03 06:00:00     18
# 1970-01-03 08:00:00     19
# 1970-01-03 10:00:00     22
# 1970-01-03 12:00:00     46
# 1970-01-03 14:00:00     65
# 1970-01-03 16:00:00     46
# 1970-01-03 18:00:00     59
# 1970-01-03 20:00:00     55
# 1970-01-03 22:00:00    120
# 1970-01-04 00:00:00    128
# 1970-01-04 02:00:00    181
# 1970-01-04 04:00:00    124
# 1970-01-04 06:00:00     36
# 1970-01-04 08:00:00     18
# 1970-01-04 10:00:00     26
# 1970-01-04 12:00:00     33
# ...

# %%
df_twohours_firstfivedays.plot(figsize=(15,4))
plt.show()

# %% [markdown]
# It looks like there are some fluctuations over the course of a day, but not necessarily in a predictable way.
